# %% [markdown]
# # 02 — Data cleaning
#
# ## Purpose
# Apply all cleaning decisions identified in `data_inspection.ipynb`.
# This notebook makes deliberate, documented changes to the raw data and
# saves a clean version to `data/processed/` for all downstream notebooks.
#
# ## Inputs
# - `data/raw/zigong/dat.csv`
# - `data/raw/zigong/dat_md.csv`
#
# ## Outputs
# - `data/processed/clinical_clean.csv`
# - `data/processed/meds_clean.csv`
#
# ## Cleaning decisions reference
# All physiological range sources are documented in `references.md`.
# All cleaning decisions are documented in the findings summary of
# `01_data_inspection.ipynb`.
